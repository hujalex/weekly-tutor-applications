# %%
import pandas as pd

# %%
df = pd.read_csv('export-tutors-2025-07-11-162954 (1).csv')

# %%
df['Date Created'].dtype
# Out:
# dtype('O')

# %%
df['Date Created'] = pd.to_datetime(df['Date Created']).dt.normalize()

# %%
weekly_groups = df.groupby(pd.Grouper(key = 'Date Created', freq = 'W'))

# %%
weekly_sum = df.groupby(pd.Grouper(key='Date Created', freq='W')).count()

# %%
weekly_sum['ID']
# Out:
# Date Created
# 2021-02-14    22
# 2021-02-21     2
# 2021-02-28     4
# 2021-03-07    11
# 2021-03-14     7
#               ..
# 2025-06-15    11
# 2025-06-22    11
# 2025-06-29    11
# 2025-07-06     4
# 2025-07-13     9
# Freq: W-SUN, Name: ID, Length: 231, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (20, 6))

sns.lineplot(data = weekly_sum['ID'])
ax = plt.gca()
# Show month names
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))  # Jan 2021
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))   # Every 6 months
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
